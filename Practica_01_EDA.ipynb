# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
games_S = pd.read_csv('Data/Athletes_summer_games.csv')
games_W = pd.read_csv('Data/Athletes_winter_games.csv')
regions = pd.read_csv('Data/regions.csv')
df = pd.concat([games_S, games_W])
del games_S, games_W

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 286237 entries, 0 to 48563
# Data columns (total 13 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Unnamed: 0  286237 non-null  int64
#  1   Name        286237 non-null  object
#  2   Sex         286237 non-null  object
#  3   Age         276763 non-null  float64
#  4   Team        286237 non-null  object
#  5   NOC         286237 non-null  object
#  6   Games       286237 non-null  object
#  7   Year        286237 non-null  int64
#  8   Season      286237 non-null  object
#  9   City        286237 non-null  object
#  10  Sport       286237 non-null  object
#  11  Event       286237 non-null  object
#  12  Medal       42232 non-null   object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 30.6+ MB

# %%
int(df['Age'].mean())
# Out:
# 25

# %%
df.head()
# Out:
#    Unnamed: 0                                Name Sex   Age            Team  \
# 0           0                           A Dijiang   M  24.0           China
# 1           1                            A Lamusi   M  23.0           China
# 2           2                 Gunnar Nielsen Aaby   M  24.0         Denmark
# 3           3                Edgar Lindenau Aabye   M  34.0  Denmark/Sweden
# 4          26  Cornelia "Cor" Aalten (-Strannood)   F  18.0     Netherlands
#
#    NOC        Games  Year  Season         City       Sport  \
# 0  CHN  1992 Summer  1992  Summer    Barcelona  Basketball
# 1  CHN  2012 Summer  2012  Summer       London        Judo
# 2  DEN  1920 Summer  1920  Summer    Antwerpen    Football
# 3  DEN  1900 Summer  1900  Summer        Paris  Tug-Of-War
# 4  NED  1932 Summer  1932  Summer  Los Angeles   Athletics
#
#                           Event Medal
# 0   Basketball Men's Basketball   NaN
# 1  Judo Men's Extra-Lightweight   NaN
# ...

# %%
diccionario_nulos = {'Age':int(df['Age'].isnull().sum())}
diccionario_nulos['Sex']=int(df['Sex'].isnull().sum())
diccionario_nulos['Team']=int(df['Team'].isnull().sum())
diccionario_nulos['NOC']=int(df['NOC'].isnull().sum())
diccionario_nulos['Games']=int(df['Games'].isnull().sum())
diccionario_nulos['Year']=int(df['Year'].isnull().sum())
diccionario_nulos['Season']=int(df['Season'].isnull().sum())
diccionario_nulos['City']=int(df['City'].isnull().sum())
diccionario_nulos['Sport']=int(df['Sport'].isnull().sum())
diccionario_nulos['Event']=int(df['Event'].isnull().sum())
diccionario_nulos['Medal']=int(df['Medal'].isnull().sum())
diccionario_nulos
# Out:
# {'Age': 9474,
#  'Sex': 0,
#  'Team': 0,
#  'NOC': 0,
#  'Games': 0,
#  'Year': 0,
#  'Season': 0,
#  'City': 0,
#  'Sport': 0,
#  'Event': 0,
#  'Medal': 244005}

# %%
diccionario_nulos['City']=int(df['City'].isnull().sum())

# %%
diccionario_nulos
# Out:
# {'Age': 9474,
#  'Sex': 0,
#  'Team': 0,
#  'NOC': 0,
#  'Games': 0,
#  'Year': 0,
#  'Season': 0,
#  'City': 0,
#  'Sport': 0,
#  'Event': 0,
#  'Medal': 244005}

# %%
df=df.drop(columns="Unnamed: 0")

# %%
df["Age"]=df["Age"].fillna(df["Age"].mean())
df["Age"]=df["Age"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 286237 entries, 0 to 48563
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    286237 non-null  object
#  1   Sex     286237 non-null  object
#  2   Age     286237 non-null  int64
#  3   Team    286237 non-null  object
#  4   NOC     286237 non-null  object
#  5   Games   286237 non-null  object
#  6   Year    286237 non-null  int64
#  7   Season  286237 non-null  object
#  8   City    286237 non-null  object
#  9   Sport   286237 non-null  object
#  10  Event   286237 non-null  object
#  11  Medal   42232 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 28.4+ MB

# %%
variables=list(diccionario_nulos.keys())
nulos=list(diccionario_nulos.values())
plt.bar(variables,nulos)
plt.xlabel("Variables")
plt.ylabel("Cantidad de nulos")
plt.title("Total de nulos por variable")
plt.xticks(rotation=90)
plt.show()

# %%
porcentaje_nulo={"Age":diccionario_nulos["Age"]/len(df),"Sex":diccionario_nulos["Sex"]/len(df),"Team":diccionario_nulos["Team"]/len(df),"NOC":diccionario_nulos["NOC"]/len(df),"Games":diccionario_nulos["Games"]/len(df),"Year":diccionario_nulos["Year"]/len(df),"Season":diccionario_nulos["Season"]/len(df),"City":diccionario_nulos["City"]/len(df),"Sport":diccionario_nulos["Sport"]/len(df),"Event":diccionario_nulos["Event"]/len(df),"Medal":diccionario_nulos["Medal"]/len(df)}

# %%
porcentaje_nulo
# Out:
# {'Age': 0.03309844639232524,
#  'Sex': 0.0,
#  'Team': 0.0,
#  'NOC': 0.0,
#  'Games': 0.0,
#  'Year': 0.0,
#  'Season': 0.0,
#  'City': 0.0,
#  'Sport': 0.0,
#  'Event': 0.0,
#  'Medal': 0.852457928220321}

# %%
data=df["Name"].value_counts().head(10)

# %%
plt.bar(data.keys(),data.values)
plt.xlabel("Atletas")
plt.ylabel("Participaciones")
plt.title("10 Atletas con mas participaciones en juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Sex"].value_counts()
plt.pie(labels=data.keys(),x=data.values, autopct='%1.1f%%')
plt.title("10 Atletas con mas participaciones en juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Age_R"]=pd.cut(x=df["Age"],bins=np.arange(10,110,10))

# %%
data=df["Age_R"]=pd.cut(x=df["Age"],bins=np.arange(10,110,10))
data=df["Age"].value_counts()
plt.bar(data.keys(),data.values)
plt.xlabel("Atletas")
plt.ylabel("Participaciones")
plt.title("")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Team"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("")
plt.ylabel("Participaciones")
plt.title("10 Atletas con mas participaciones en juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["NOC"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("")
plt.ylabel("Participaciones")
plt.title("10 Atletas con mas participaciones en juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Games"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("")
plt.ylabel("Participaciones")
plt.title("juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Year"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("")
plt.ylabel("Participaciones")
plt.title("10 años en juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Season"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("")
plt.ylabel("Participaciones")
plt.title("10 Atletas con mas participaciones en juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["City"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("")
plt.ylabel("")
plt.title("")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Sport"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("")
plt.ylabel("")
plt.title("")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Event"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("")
plt.ylabel("Participaciones")
plt.title("Juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
data=df["Medal"].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xlabel("categorias de medallas ")
plt.ylabel("porcetaje")
plt.title("tipos de medallas de los juegos olimpicos")
plt.xticks(rotation=90)
plt.show()

# %%
filtro = df[df['Medal']== 'Gold']
filtro['Team'].value_counts()


filtro =df[df['Medal'].notnull()]

# %%
filtro
# Out:
#                             Name Sex  Age            Team  NOC        Games  \
# 3           Edgar Lindenau Aabye   M   34  Denmark/Sweden  DEN  1900 Summer
# 12          Arvo Ossian Aaltonen   M   30         Finland  FIN  1920 Summer
# 13          Arvo Ossian Aaltonen   M   30         Finland  FIN  1920 Summer
# 15       Paavo Johannes Aaltonen   M   28         Finland  FIN  1948 Summer
# 16       Paavo Johannes Aaltonen   M   28         Finland  FIN  1948 Summer
# ...                          ...  ..  ...             ...  ...          ...
# 48405  Sergey Mikhaylovich Zubov   M   21    Unified Team  EUN  1992 Winter
# 48449                Matja Zupan   M   19      Yugoslavia  YUG  1988 Winter
# 48481          Pirmin Zurbriggen   M   25     Switzerland  SUI  1988 Winter
# 48483          Pirmin Zurbriggen   M   25     Switzerland  SUI  1988 Winter
# 48491          Silvan Zurbriggen   M   28     Switzerland  SUI  2010 Winter
#
#        Year  Season         City          Sport  \
# ...

# %%
data = df['City'].value_counts().head(10)
plt.bar(data.keys(),data.values)
plt.xticks(rotation=90)
plt.xlabel('Ciudades con más participantes')
plt.ylabel('Num participaciones')
plt.title('City')
plt.show()

# %%
data
# Out:
# City
# Tokyo             22823
# London            22426
# Athina            15556
# Sydney            13821
# Atlanta           13780
# Rio de Janeiro    13688
# Beijing           13602
# Barcelona         12977
# Los Angeles       12423
# Seoul             12037
# Name: count, dtype: int64

# %%
df['Age_R'] = df['Age_R'].astype(str)

# %%
df.to_parquet('Data/Dataset.parquet')
